# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_excel('../data/3303_1 underlying causes of death (australia).xls',
                  )

# %%
df
# Out:
#                       Australian Bureau of Statistics  \
# 0             3303.0 Causes of Death, Australia, 2018
# 1   Released at 11.30am (Canberra time) 25 Septemb...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
